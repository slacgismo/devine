# %%
from zeep import Client
from zeep.helpers import serialize_object
from zeep.wsse.username import UsernameToken
from datetime import datetime, timedelta
import pandas as pd
import json

class CP_API:
    def __init__(self):
        self.username = '92d0023b4f07baa1857381a51de78772546674ef2b8391416000751'
        self.password = 'c2f058fc77298198f5bb3089cb354053'
#         self.username = '7f74b2f7226e5cf50d59e84cc628649f5dadd5a5234f51571673509'
#         self.password = '20287bf991b521edbd6bd2b5c83feed4'
        self.wsdl_url = "https://webservices.chargepoint.com/cp_api_5.0.wsdl"
        self.client = Client(self.wsdl_url, wsse=UsernameToken(self.username, self.password))

    def getSession(self, tStart, tEnd):

        usageSearchQuery = {'fromTimeStamp': tStart, 'toTimeStamp': tEnd,}
        data = self.client.service.getChargingSessionData(usageSearchQuery)
#         print('session data: ', data['ChargingSessionData'])
        df = pd.DataFrame(data['ChargingSessionData'])
        return data

    def shedLoad(self, stationID, allowedLoadStation, portNumber, allowedLoadPort, timeInterval=0):
        # load is in kW
        usageSearchQuery = {'stationID': stationID}
        pass
    
    def clearShedState(self, ):
        pass
    
    def getLoad(self):
        usageSearchQuery = {'stationID': '1:113189'}
        data = self.client.service.getLoad(usageSearchQuery)
        return data
    
    def getCPNInstance(self):
        data = self.client.service.getCPNInstances()
        return data
    
    def getOrgsAndStationsGroups(self):
        data = self.client.service.getCPNInstances()
        return data
    
    
    
cp = CP_API()
tStart = datetime(2020, 2, 13, 00, 00, 00)
tEnd = tStart + timedelta(hours=23, minutes=59, seconds=59)
data = cp.getSession(tStart, tEnd)
CPNI = cp.getLoad()

# %%
CPNI
# Out:
# {
#     'responseCode': '101',
#     'responseText': 'You are not authorized to access this API call, because your ChargePoint Cloud Plan does not let you run this call. Please contact ChargePoint Customer Support to upgrade your Cloud Plan.',
#     'sgID': None,
#     'numStations': None,
#     'groupName': None,
#     'sgLoad': None,
#     'stationData': []
# }

# %%
# print('Data: ', data)
NewDict = {}  # Initialize a new dictionary
for listItem in data['ChargingSessionData']:
    for key, value in listItem.items():  # Loop through all dictionary elements in the list
        if key in list(NewDict):  # if the key already exists, append to new
            for entry in value:
                NewDict[key].append(entry)
        else:  # if it's a new key, simply add to the new dictionary
            NewDict[key] = value

df = pd.DataFrame(NewDict)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/venv_devine/lib/python3.7/site-packages/zeep/xsd/valueobjects.py in __getattribute__(self, key)
#     142         try:
# --> 143             return self.__values__[key]
#     144         except KeyError:
#
# KeyError: 'items'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-7d214505dba5> in <module>
#       2 NewDict = {}  # Initialize a new dictionary
#       3 for listItem in data['ChargingSessionData']:
# ----> 4     for key, value in listItem.items():  # Loop through all dictionary elements in the list
#       5         if key in list(NewDict):  # if the key already exists, append to new
#       6             for entry in value:
#
# ~/opt/anaconda3/envs/venv_devine/lib/python3.7/site-packages/zeep/xsd/valueobjects.py in __getattribute__(self, key)
#     144         except KeyError:
#     145             raise AttributeError(
# --> 146                 "%s instance has no attribute '%s'" % (self.__class__.__name__, key)
#     147             )
#     148
#
# AttributeError: sessionSearchResultdata instance has no attribute 'items'

# %%
a = data['ChargingSessionData'][0]
a['stationID']
# Out:
# '1:113189'

# %%
test = serialize_object(data['ChargingSessionData'])

# data['ChargingSessionData']
# Out:
# odict_keys(['stationID', 'stationName', 'portNumber', 'Address', 'City', 'State', 'Country', 'postalCode', 'sessionID', 'Energy', 'startTime', 'endTime', 'userID', 'recordNumber', 'credentialID'])

# %%
data['ChargingSessionData'][0]
# Out:
# {
#     'stationID': '1:113189',
#     'stationName': 'SLAC / SUSB CHARGER 1',
#     'portNumber': '2',
#     'Address': 'Loop Rd, Menlo Park, California, 94025, United States',
#     'City': 'Menlo Park',
#     'State': 'California',
#     'Country': 'United States',
#     'postalCode': '94025',
#     'sessionID': 658538251,
#     'Energy': 6.564005,
#     'startTime': datetime.datetime(2020, 2, 12, 17, 48, 51, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#     'endTime': datetime.datetime(2020, 2, 13, 0, 32, 20, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#     'userID': '185231',
#     'recordNumber': 1,
#     'credentialID': 'CNCP0000192758'
# }

# %%
df = pd.DataFrame(test)

# %%
df.head(30)
# Out:
#    stationID            stationName portNumber  \
# 0   1:113189  SLAC / SUSB CHARGER 1          2
# 1   1:113189  SLAC / SUSB CHARGER 1          1
# 2   1:112413  SLAC / SUSB CHARGER 3          1
# 3   1:112413  SLAC / SUSB CHARGER 3          2
# 4   1:113177  SLAC / SUSB CHARGER 2          1
# 5   1:112413  SLAC / SUSB CHARGER 3          1
# 6   1:113177  SLAC / SUSB CHARGER 2          1
# 7   1:113177  SLAC / SUSB CHARGER 2          2
# 8   1:113189  SLAC / SUSB CHARGER 1          1
# 9   1:113177  SLAC / SUSB CHARGER 2          1
# 10  1:113177  SLAC / SUSB CHARGER 2          1
# 11  1:113189  SLAC / SUSB CHARGER 1          2
# 12  1:112413  SLAC / SUSB CHARGER 3          1
# 13  1:113189  SLAC / SUSB CHARGER 1          1
# 14  1:113177  SLAC / SUSB CHARGER 2          1
#
#                                               Address            City  \
# 0   Loop Rd, Menlo Park, California, 94025, United...      Menlo Park
# 1   Loop Rd, Menlo Park, California, 94025, United...      Menlo Park
# 2   Loop Rd, Portola Valley, California, 94028, Un...  Portola Valley
# 3   Loop Rd, Portola Valley, California, 94028, Un...  Portola Valley
# 4   Loop Rd, Portola Valley, California, 94028, Un...  Portola Valley
# 5   Loop Rd, Portola Valley, California, 94028, Un...  Portola Valley
# 6   Loop Rd, Portola Valley, California, 94028, Un...  Portola Valley
# 7   Loop Rd, Portola Valley, California, 94028, Un...  Portola Valley
# 8   Loop Rd, Menlo Park, California, 94025, United...      Menlo Park
# 9   Loop Rd, Portola Valley, California, 94028, Un...  Portola Valley
# 10  Loop Rd, Portola Valley, California, 94028, Un...  Portola Valley
# 11  Loop Rd, Menlo Park, California, 94025, United...      Menlo Park
# 12  Loop Rd, Portola Valley, California, 94028, Un...  Portola Valley
# 13  Loop Rd, Menlo Park, California, 94025, United...      Menlo Park
# 14  Loop Rd, Portola Valley, California, 94028, Un...  Portola Valley
#
#          State        Country postalCode  sessionID     Energy  \
# 0   California  United States      94025  658538251   6.564005
# 1   California  United States      94025  658700791  27.418077
# 2   California  United States      94028  658850791   8.263345
# 3   California  United States      94028  658926531  17.505075
# 4   California  United States      94028  658879201  34.695351
# 5   California  United States      94028  659158821  37.598557
# 6   California  United States      94028  659353781   6.422869
# 7   California  United States      94028  659295851   8.384498
# 8   California  United States      94025  659337691  15.907853
# 9   California  United States      94028  659565371  11.378371
# 10  California  United States      94028  659694611   4.733644
# 11  California  United States      94025  659321781  12.325292
# 12  California  United States      94028  659321931  36.965996
# 13  California  United States      94025  659685611  15.842430
# 14  California  United States      94028  659832281   8.178070
#
#                    startTime                   endTime    userID  \
# 0  2020-02-12 17:48:51+00:00 2020-02-13 00:32:20+00:00    185231
# 1  2020-02-12 20:13:30+00:00 2020-02-13 00:47:45+00:00   3339191
# 2  2020-02-12 22:29:00+00:00 2020-02-13 01:37:07+00:00    826091
# 3  2020-02-12 23:47:22+00:00 2020-02-13 02:43:44+00:00   2052611
# 4  2020-02-12 22:57:53+00:00 2020-02-13 06:01:52+00:00   4321501
# 5  2020-02-13 05:59:44+00:00 2020-02-13 14:01:36+00:00  19775251
# 6  2020-02-13 15:10:32+00:00 2020-02-13 17:26:34+00:00    357265
# 7  2020-02-13 14:12:36+00:00 2020-02-13 17:51:46+00:00  21551071
# 8  2020-02-13 14:56:57+00:00 2020-02-13 18:19:43+00:00    826091
# 9  2020-02-13 17:29:46+00:00 2020-02-13 19:23:10+00:00   2052611
# 10 2020-02-13 19:26:40+00:00 2020-02-13 21:02:25+00:00   1562851
# 11 2020-02-13 14:41:27+00:00 2020-02-13 21:17:16+00:00    394659
# 12 2020-02-13 14:41:41+00:00 2020-02-13 21:40:13+00:00   3339191
# 13 2020-02-13 19:17:40+00:00 2020-02-13 22:02:41+00:00   4321501
# 14 2020-02-13 21:22:06+00:00 2020-02-13 22:53:00+00:00   2052611
#
#     recordNumber          credentialID
# 0              1        CNCP0000192758
# 1              2  NTk4Yzk0NWYtNTdkYi00
# 2              3            OE10188750
# 3              4  NzBjYzAzMjYtOWM1Zi00
# 4              5  NjUyNTgyOTctZTk1Mi00
# 5              6  NjBhMGYyNWItZGJmMy00
# 6              7        CNCP0000220460
# 7              8  ZGJiN2NiNDAtYjZmYy00
# 8              9            OE10188750
# 9             10  NzBjYzAzMjYtOWM1Zi00
# 10            11        CNCP0000194651
# 11            12        CNCP0000487677
# 12            13  NTk4Yzk0NWYtNTdkYi00
# 13            14  NjUyNTgyOTctZTk1Mi00
# 14            15  NzBjYzAzMjYtOWM1Zi00

# %%
data
# Out:
# {
#     'responseCode': '100',
#     'responseText': 'API input request executed successfully.',
#     'ChargingSessionData': [
#         {
#             'stationID': '1:113189',
#             'stationName': 'SLAC / SUSB CHARGER 1',
#             'portNumber': '2',
#             'Address': 'Loop Rd, Menlo Park, California, 94025, United States',
#             'City': 'Menlo Park',
#             'State': 'California',
#             'Country': 'United States',
#             'postalCode': '94025',
#             'sessionID': 658538251,
#             'Energy': 6.564005,
#             'startTime': datetime.datetime(2020, 2, 12, 17, 48, 51, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'endTime': datetime.datetime(2020, 2, 13, 0, 32, 20, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'userID': '185231',
#             'recordNumber': 1,
#             'credentialID': 'CNCP0000192758'
#         },
#         {
#             'stationID': '1:113189',
#             'stationName': 'SLAC / SUSB CHARGER 1',
#             'portNumber': '1',
#             'Address': 'Loop Rd, Menlo Park, California, 94025, United States',
#             'City': 'Menlo Park',
#             'State': 'California',
#             'Country': 'United States',
#             'postalCode': '94025',
#             'sessionID': 658700791,
#             'Energy': 27.418077,
#             'startTime': datetime.datetime(2020, 2, 12, 20, 13, 30, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'endTime': datetime.datetime(2020, 2, 13, 0, 47, 45, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'userID': '3339191',
#             'recordNumber': 2,
#             'credentialID': 'NTk4Yzk0NWYtNTdkYi00'
#         },
#         {
#             'stationID': '1:112413',
#             'stationName': 'SLAC / SUSB CHARGER 3',
#             'portNumber': '1',
#             'Address': 'Loop Rd, Portola Valley, California, 94028, United States',
#             'City': 'Portola Valley',
#             'State': 'California',
#             'Country': 'United States',
#             'postalCode': '94028',
#             'sessionID': 658850791,
#             'Energy': 8.263345,
#             'startTime': datetime.datetime(2020, 2, 12, 22, 29, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'endTime': datetime.datetime(2020, 2, 13, 1, 37, 7, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'userID': '826091',
#             'recordNumber': 3,
#             'credentialID': 'OE10188750'
#         },
#         {
#             'stationID': '1:112413',
#             'stationName': 'SLAC / SUSB CHARGER 3',
#             'portNumber': '2',
#             'Address': 'Loop Rd, Portola Valley, California, 94028, United States',
#             'City': 'Portola Valley',
#             'State': 'California',
#             'Country': 'United States',
#             'postalCode': '94028',
#             'sessionID': 658926531,
#             'Energy': 17.505075,
#             'startTime': datetime.datetime(2020, 2, 12, 23, 47, 22, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'endTime': datetime.datetime(2020, 2, 13, 2, 43, 44, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'userID': '2052611',
#             'recordNumber': 4,
#             'credentialID': 'NzBjYzAzMjYtOWM1Zi00'
#         },
#         {
#             'stationID': '1:113177',
#             'stationName': 'SLAC / SUSB CHARGER 2',
#             'portNumber': '1',
#             'Address': 'Loop Rd, Portola Valley, California, 94028, United States',
#             'City': 'Portola Valley',
#             'State': 'California',
#             'Country': 'United States',
#             'postalCode': '94028',
#             'sessionID': 658879201,
#             'Energy': 34.695351,
#             'startTime': datetime.datetime(2020, 2, 12, 22, 57, 53, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'endTime': datetime.datetime(2020, 2, 13, 6, 1, 52, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'userID': '4321501',
#             'recordNumber': 5,
#             'credentialID': 'NjUyNTgyOTctZTk1Mi00'
#         },
#         {
#             'stationID': '1:112413',
#             'stationName': 'SLAC / SUSB CHARGER 3',
#             'portNumber': '1',
#             'Address': 'Loop Rd, Portola Valley, California, 94028, United States',
#             'City': 'Portola Valley',
#             'State': 'California',
#             'Country': 'United States',
#             'postalCode': '94028',
#             'sessionID': 659158821,
#             'Energy': 37.598557,
#             'startTime': datetime.datetime(2020, 2, 13, 5, 59, 44, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'endTime': datetime.datetime(2020, 2, 13, 14, 1, 36, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'userID': '19775251',
#             'recordNumber': 6,
#             'credentialID': 'NjBhMGYyNWItZGJmMy00'
#         },
#         {
#             'stationID': '1:113177',
#             'stationName': 'SLAC / SUSB CHARGER 2',
#             'portNumber': '1',
#             'Address': 'Loop Rd, Portola Valley, California, 94028, United States',
#             'City': 'Portola Valley',
#             'State': 'California',
#             'Country': 'United States',
#             'postalCode': '94028',
#             'sessionID': 659353781,
#             'Energy': 6.422869,
#             'startTime': datetime.datetime(2020, 2, 13, 15, 10, 32, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'endTime': datetime.datetime(2020, 2, 13, 17, 26, 34, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'userID': '357265',
#             'recordNumber': 7,
#             'credentialID': 'CNCP0000220460'
#         },
#         {
#             'stationID': '1:113177',
#             'stationName': 'SLAC / SUSB CHARGER 2',
#             'portNumber': '2',
#             'Address': 'Loop Rd, Portola Valley, California, 94028, United States',
#             'City': 'Portola Valley',
#             'State': 'California',
#             'Country': 'United States',
#             'postalCode': '94028',
#             'sessionID': 659295851,
#             'Energy': 8.384498,
#             'startTime': datetime.datetime(2020, 2, 13, 14, 12, 36, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'endTime': datetime.datetime(2020, 2, 13, 17, 51, 46, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'userID': '21551071',
#             'recordNumber': 8,
#             'credentialID': 'ZGJiN2NiNDAtYjZmYy00'
#         },
#         {
#             'stationID': '1:113189',
#             'stationName': 'SLAC / SUSB CHARGER 1',
#             'portNumber': '1',
#             'Address': 'Loop Rd, Menlo Park, California, 94025, United States',
#             'City': 'Menlo Park',
#             'State': 'California',
#             'Country': 'United States',
#             'postalCode': '94025',
#             'sessionID': 659337691,
#             'Energy': 15.907853,
#             'startTime': datetime.datetime(2020, 2, 13, 14, 56, 57, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'endTime': datetime.datetime(2020, 2, 13, 18, 19, 43, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'userID': '826091',
#             'recordNumber': 9,
#             'credentialID': 'OE10188750'
#         },
#         {
#             'stationID': '1:113177',
#             'stationName': 'SLAC / SUSB CHARGER 2',
#             'portNumber': '1',
#             'Address': 'Loop Rd, Portola Valley, California, 94028, United States',
#             'City': 'Portola Valley',
#             'State': 'California',
#             'Country': 'United States',
#             'postalCode': '94028',
#             'sessionID': 659565371,
#             'Energy': 11.378371,
#             'startTime': datetime.datetime(2020, 2, 13, 17, 29, 46, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'endTime': datetime.datetime(2020, 2, 13, 19, 23, 10, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'userID': '2052611',
#             'recordNumber': 10,
#             'credentialID': 'NzBjYzAzMjYtOWM1Zi00'
#         },
#         {
#             'stationID': '1:113177',
#             'stationName': 'SLAC / SUSB CHARGER 2',
#             'portNumber': '1',
#             'Address': 'Loop Rd, Portola Valley, California, 94028, United States',
#             'City': 'Portola Valley',
#             'State': 'California',
#             'Country': 'United States',
#             'postalCode': '94028',
#             'sessionID': 659694611,
#             'Energy': 4.733644,
#             'startTime': datetime.datetime(2020, 2, 13, 19, 26, 40, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'endTime': datetime.datetime(2020, 2, 13, 21, 2, 25, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'userID': '1562851',
#             'recordNumber': 11,
#             'credentialID': 'CNCP0000194651'
#         },
#         {
#             'stationID': '1:113189',
#             'stationName': 'SLAC / SUSB CHARGER 1',
#             'portNumber': '2',
#             'Address': 'Loop Rd, Menlo Park, California, 94025, United States',
#             'City': 'Menlo Park',
#             'State': 'California',
#             'Country': 'United States',
#             'postalCode': '94025',
#             'sessionID': 659321781,
#             'Energy': 12.325292,
#             'startTime': datetime.datetime(2020, 2, 13, 14, 41, 27, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'endTime': datetime.datetime(2020, 2, 13, 21, 17, 16, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'userID': '394659',
#             'recordNumber': 12,
#             'credentialID': 'CNCP0000487677'
#         },
#         {
#             'stationID': '1:112413',
#             'stationName': 'SLAC / SUSB CHARGER 3',
#             'portNumber': '1',
#             'Address': 'Loop Rd, Portola Valley, California, 94028, United States',
#             'City': 'Portola Valley',
#             'State': 'California',
#             'Country': 'United States',
#             'postalCode': '94028',
#             'sessionID': 659321931,
#             'Energy': 36.965996,
#             'startTime': datetime.datetime(2020, 2, 13, 14, 41, 41, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'endTime': datetime.datetime(2020, 2, 13, 21, 40, 13, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'userID': '3339191',
#             'recordNumber': 13,
#             'credentialID': 'NTk4Yzk0NWYtNTdkYi00'
#         },
#         {
#             'stationID': '1:113189',
#             'stationName': 'SLAC / SUSB CHARGER 1',
#             'portNumber': '1',
#             'Address': 'Loop Rd, Menlo Park, California, 94025, United States',
#             'City': 'Menlo Park',
#             'State': 'California',
#             'Country': 'United States',
#             'postalCode': '94025',
#             'sessionID': 659685611,
#             'Energy': 15.84243,
#             'startTime': datetime.datetime(2020, 2, 13, 19, 17, 40, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'endTime': datetime.datetime(2020, 2, 13, 22, 2, 41, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'userID': '4321501',
#             'recordNumber': 14,
#             'credentialID': 'NjUyNTgyOTctZTk1Mi00'
#         },
#         {
#             'stationID': '1:113177',
#             'stationName': 'SLAC / SUSB CHARGER 2',
#             'portNumber': '1',
#             'Address': 'Loop Rd, Portola Valley, California, 94028, United States',
#             'City': 'Portola Valley',
#             'State': 'California',
#             'Country': 'United States',
#             'postalCode': '94028',
#             'sessionID': 659832281,
#             'Energy': 8.17807,
#             'startTime': datetime.datetime(2020, 2, 13, 21, 22, 6, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'endTime': datetime.datetime(2020, 2, 13, 22, 53, tzinfo=<isodate.tzinfo.Utc object at 0x1097b0750>),
#             'userID': '2052611',
#             'recordNumber': 15,
#             'credentialID': 'NzBjYzAzMjYtOWM1Zi00'
#         }
#     ],
#     'MoreFlag': 0
# }

# %%
# !jupyter nbconvert --to script API.ipynb
# Out:
# [NbConvertApp] Converting notebook API.ipynb to script
# [NbConvertApp] Writing 2713 bytes to API.py
